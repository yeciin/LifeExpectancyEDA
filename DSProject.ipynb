# %%
import pandas as pd
df = pd.read_csv("LifeExpectancyWHO.csv")
'''
Country
List of the 179 countries
1
Region
179 countries are distributed in 9 regions. E.g. Africa, Asia, Oceania, European Union, Rest of Europe and etc.

Year
Years observed from 2000 to 2015

Infant_deaths
Represents infant deaths per 1000 population

Under_five_deaths
Represents deaths of children under five years old per 1000 population

Adult_mortality
Represents deaths of adults per 1000 population

Alcohol_consumption
Represents alcohol consumption that is recorded in liters of pure alcohol per capita with 15+ years old

Hepatitis_B
Represents % of coverage of Hepatitis B (HepB3) immunization among 1-year-olds.

Measles
Represents % of coverage of Measles containing vaccine first dose (MCV1) immunization among 1-year-olds

BMI
BMI is a measure of nutritional status in adults. It is defined as a person's weight in kilograms divided by the square of their height
'''
# Out:
# "\nCountry\nList of the 179 countries\n1\nRegion\n179 countries are distributed in 9 regions. E.g. Africa, Asia, Oceania, European Union, Rest of Europe and etc.\n\nYear\nYears observed from 2000 to 2015\n\nInfant_deaths\nRepresents infant deaths per 1000 population\n\nUnder_five_deaths\nRepresents deaths of children under five years old per 1000 population\n\nAdult_mortality\nRepresents deaths of adults per 1000 population\n\nAlcohol_consumption\nRepresents alcohol consumption that is recorded in liters of pure alcohol per capita with 15+ years old\n\nHepatitis_B\nRepresents % of coverage of Hepatitis B (HepB3) immunization among 1-year-olds.\n\nMeasles\nRepresents % of coverage of Measles containing vaccine first dose (MCV1) immunization among 1-year-olds\n\nBMI\nBMI is a measure of nutritional status in adults. It is defined as a person's weight in kilograms divided by the square of their height\n"

# %%
#Get rid of any empty data
df.dropna(inplace=True)

# %%
df2000=df[df['Year'] == 2000]
df2001=df[df['Year'] == 2001]
df2002=df[df['Year'] == 2002]
df2003=df[df['Year'] == 2003]
df2004=df[df['Year'] == 2004]
df2005=df[df['Year'] == 2005]
df2006=df[df['Year'] == 2006]
df2007=df[df['Year'] == 2007]
df2008=df[df['Year'] == 2008]
df2009=df[df['Year'] == 2009]
df2010=df[df['Year'] == 2010]
df2011=df[df['Year'] == 2011]
df2012=df[df['Year'] == 2012]
df2013=df[df['Year'] == 2013]
df2014=df[df['Year'] == 2014]
df2015=df[df['Year'] == 2015]

# %%
print(df.head())
# Out:
#    Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 0  Turkiye     Middle East  2015           11.1               13.0
# 1    Spain  European Union  2015            2.7                3.3
# 2    India            Asia  2007           51.5               67.9
# 3   Guyana   South America  2006           32.8               40.5
# 4   Israel     Middle East  2012            3.4                4.3
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 0         105.8240                 1.32           97       65  27.8  ...
# 1          57.9025                10.35           97       94  26.0  ...
# 2         201.0765                 1.57           60       35  21.2  ...
# 3         222.1965                 5.68           93       74  25.3  ...
# 4          57.9510                 2.89           97       89  27.0  ...
#
#    Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# ...

# %%
print(df.describe())
# Out:
#               Year  Infant_deaths  Under_five_deaths  Adult_mortality  \
# count  2864.000000    2864.000000        2864.000000      2864.000000
# mean   2007.500000      30.363792          42.938268       192.251775
# std       4.610577      27.538117          44.569974       114.910281
# min    2000.000000       1.800000           2.300000        49.384000
# 25%    2003.750000       8.100000           9.675000       106.910250
# 50%    2007.500000      19.600000          23.100000       163.841500
# 75%    2011.250000      47.350000          66.000000       246.791375
# max    2015.000000     138.100000         224.900000       719.360500
#
#        Alcohol_consumption  Hepatitis_B      Measles          BMI  \
# count          2864.000000  2864.000000  2864.000000  2864.000000
# mean              4.820882    84.292598    77.344972    25.032926
# std               3.981949    15.995511    18.659693     2.193905
# min               0.000000    12.000000    10.000000    19.800000
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2864 entries, 0 to 2863
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      2864 non-null   object
#  1   Region                       2864 non-null   object
#  2   Year                         2864 non-null   int64
#  3   Infant_deaths                2864 non-null   float64
#  4   Under_five_deaths            2864 non-null   float64
#  5   Adult_mortality              2864 non-null   float64
#  6   Alcohol_consumption          2864 non-null   float64
#  7   Hepatitis_B                  2864 non-null   int64
#  8   Measles                      2864 non-null   int64
#  9   BMI                          2864 non-null   float64
#  10  Polio                        2864 non-null   int64
#  11  Diphtheria                   2864 non-null   int64
#  12  Incidents_HIV                2864 non-null   float64
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# Visualize life expectancy over the years
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Life_expectancy', data=df, hue='Region')
plt.title('Life Expectancy Over the Years by Region')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Calculate mean life expectancy by region
mean_life_expectancy_by_region = df.groupby('Region')['Life_expectancy'].mean()
print(mean_life_expectancy_by_region)

# Calculate mean alcohol consumption by year
mean_alcohol_by_year = df.groupby('Year')['Alcohol_consumption'].mean()
print(mean_alcohol_by_year)
# Out:
# Region
# Africa                           57.847304
# Asia                             69.454861
# Central America and Caribbean    72.437500
# European Union                   77.715046
# Middle East                      73.975446
# North America                    77.841667
# Oceania                          69.517614
# Rest of Europe                   74.525417
# South America                    72.780729
# Name: Life_expectancy, dtype: float64
# Year
# 2000    4.770000
# 2001    4.760559
# 2002    4.775933
# 2003    4.759514
# 2004    4.775782
# 2005    4.857354
# 2006    4.923191
# 2007    5.012806
# 2008    4.986855
# 2009    4.803006
# 2010    4.790279
# 2011    4.822402
# 2012    4.827933
# 2013    4.777318
# 2014    4.762179
# 2015    4.728994
# Name: Alcohol_consumption, dtype: float64

# %%
#distribution of infant deaths
plt.figure(figsize=(8, 6))
sns.histplot(df['Infant_deaths'], bins=20, kde=True)
plt.title('Distribution of Infant Deaths')
plt.xlabel('Infant Deaths per 1000 Population')
plt.ylabel('Frequency')
plt.show()

# %%
#Average Life Expectancy by Region
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Life_expectancy', data=df)
plt.title('Average Life Expectancy by Region')
plt.xlabel('Region')
plt.ylabel('Average Life Expectancy')
plt.xticks(rotation=45)
plt.show()

# %%
#Distribution of Alcohol Consumption
plt.figure(figsize=(8, 6))
sns.histplot(df['Alcohol_consumption'], bins=20, kde=True)
plt.title('Distribution of Alcohol Consumption')
plt.xlabel('Alcohol Consumption (Liters per Capita)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='Infant_deaths', data=df)
plt.title('Infant Deaths by Region')
plt.xlabel('Region')
plt.ylabel('Infant Deaths per 1000 Population')
plt.xticks(rotation=45)
plt.show()

# %%
column_titles = [f"'{col}'" for col in df.columns]
print(', '.join(column_titles))

#Listing the columns in a format so they can be used in the next graph
# Out:
# 'Country', 'Region', 'Year', 'Infant_deaths', 'Under_five_deaths', 'Adult_mortality', 'Alcohol_consumption', 'Hepatitis_B', 'Measles', 'BMI', 'Polio', 'Diphtheria', 'Incidents_HIV', 'GDP_per_capita', 'Population_mln', 'Thinness_ten_nineteen_years', 'Thinness_five_nine_years', 'Schooling', 'Economy_status_Developed', 'Economy_status_Developing', 'Life_expectancy'

# %%
sns.pairplot(df[['BMI', 'Life_expectancy', 'Measles', 'GDP_per_capita', 'Alcohol_consumption']])
plt.suptitle('Pair Plot of Numeric Features', y=1.02)
plt.show()

# %%
mean_life_alcohol = df.groupby('Region')['Life_expectancy', 'Alcohol_consumption'].mean()
print(mean_life_alcohol)
# Out:
#                                Life_expectancy  Alcohol_consumption
# Region
# Africa                               57.847304             2.980694
# Asia                                 69.454861             2.401700
# Central America and Caribbean        72.437500             5.623224
# European Union                       77.715046            10.791319
# Middle East                          73.975446             0.884161
# North America                        77.841667             7.053125
# Oceania                              69.517614             2.880239
# Rest of Europe                       74.525417             7.580083
# South America                        72.780729             5.745677
# C:\Users\USER\AppData\Local\Temp\ipykernel_524\766196282.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   mean_life_alcohol = df.groupby('Region')['Life_expectancy', 'Alcohol_consumption'].mean()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Region', y='Adult_mortality', data=df)
plt.title('Distribution of Adult Mortality by Region')
plt.xlabel('Region')
plt.ylabel('Adult Mortality per 1000 Population')
plt.xticks(rotation=45)
plt.show()

# %%
top_10_countries_high = df2000.nlargest(10, 'Life_expectancy')
lowest_10_countries = df2000.nsmallest(10, 'Life_expectancy')
combined_df = pd.concat([top_10_countries_high, lowest_10_countries]) #concatonate the two data frames

fig, ax = plt.subplots(figsize=(10, 8))

# Plot the data for highest life expectancy
ax.barh(combined_df['Country'][:10], combined_df['Life_expectancy'][:10], color='skyblue', label='Highest')

# Plot the data for lowest life expectancy
ax.barh(combined_df['Country'][10:], combined_df['Life_expectancy'][10:], color='orange', label='Lowest')

ax.set_title('Top 10 Countries with Highest and Lowest Life Expectancy 2000')
ax.set_xlabel('Life Expectancy')
ax.set_ylabel('Country')
ax.legend(title='Life Expectancy')


plt.show()

# %%
top_10_countries_high = df2015.nlargest(10, 'Life_expectancy')
lowest_10_countries = df2015.nsmallest(10, 'Life_expectancy')

combined_df = pd.concat([top_10_countries_high, lowest_10_countries])

fig, ax = plt.subplots(figsize=(10, 8))

# Plot the data for highest life expectancy
ax.barh(combined_df['Country'][:10], combined_df['Life_expectancy'][:10], color='skyblue', label='Highest')

# Plot the data for lowest life expectancy
ax.barh(combined_df['Country'][10:], combined_df['Life_expectancy'][10:], color='orange', label='Lowest')

ax.set_title('Top 10 Countries with Highest and Lowest Life Expectancy 2015')
ax.set_xlabel('Life Expectancy')
ax.set_ylabel('Country')
ax.legend(title='Life Expectancy')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='BMI', y='Life_expectancy', data=df, hue='Region', palette='muted')
plt.title('Life Expectancy vs. BMI by Region')
plt.xlabel('BMI')
plt.ylabel('Life Expectancy')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=(12, 8))
# BMI vs. Life Expectancy 2000
plt.subplot(2, 2, 1)
plt.scatter(df2000['BMI'], df2000['Life_expectancy'], color='skyblue')
plt.title('BMI vs. Life Expectancy 2000')
plt.xlabel('BMI')
plt.ylabel('Life Expectancy')

# BMI vs. Life Expectancy 2005
plt.subplot(2, 2, 2)
plt.scatter(df2005['BMI'], df2005['Life_expectancy'], color='salmon')
plt.title('BMI vs. Life Expectancy 2005')
plt.xlabel('BMI')
plt.ylabel('Life Expectancy')

# BMI vs. Life Expectancy 2010
plt.subplot(2, 2, 3)
plt.scatter(df2010['BMI'], df2010['Life_expectancy'], color='skyblue')
plt.title('BMI vs. Life Expectancy 2010')
plt.xlabel('BMI')
plt.ylabel('Life Expectancy')

# BMI vs. Life Expectancy 2015
plt.subplot(2, 2, 4)
plt.scatter(df2015['BMI'], df2015['Life_expectancy'], color='salmon')
plt.title('BMI vs. Life Expectancy 2015')
plt.xlabel('BMI')
plt.ylabel('Life Expectancy')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

# Hepatitis B Vaccination vs. Life Expectancy 2000
plt.subplot(2, 2, 1)
plt.scatter(df2000['Hepatitis_B'], df2000['Life_expectancy'], color='green')
plt.title('Hepatitis B Vaccination vs. Life Expectancy 2000')
plt.xlabel('Hepatitis B Vaccination (% of Coverage)')
plt.ylabel('Life Expectancy')

# Hepatitis B Vaccination vs. Life Expectancy 2005
plt.subplot(2, 2, 2)
plt.scatter(df2005['Hepatitis_B'], df2005['Life_expectancy'], color='orange')
plt.title('Hepatitis B Vaccination vs. Life Expectancy 2005')
plt.xlabel('Hepatitis B Vaccination (% of Coverage)')
plt.ylabel('Life Expectancy')

# Hepatitis B Vaccination vs. Life Expectancy 2010
plt.subplot(2, 2, 3)
plt.scatter(df2010['Hepatitis_B'], df2010['Life_expectancy'], color='orange')
plt.title('Hepatitis B Vaccination vs. Life Expectancy 2010')
plt.xlabel('Hepatitis B Vaccination (% of Coverage)')
plt.ylabel('Life Expectancy')

# Hepatitis B Vaccination vs. Life Expectancy 2015
plt.subplot(2, 2, 4)
plt.scatter(df2015['Hepatitis_B'], df2015['Life_expectancy'], color='orange')
plt.title('Hepatitis B Vaccination vs. Life Expectancy 2015')
plt.xlabel('Hepatitis B Vaccination (% of Coverage)')
plt.ylabel('Life Expectancy')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Alcohol_consumption', data=df)
plt.title('Average Alcohol Consumption by Region')
plt.xlabel('Region')
plt.ylabel('Average Alcohol Consumption')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Life_expectancy', data=df)
plt.title('Life Expectancy Over the Years')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.show()

# %%
#Visualize correlations between numeric features
correlation_matrix = df.corr()
plt.figure(figsize=(18, 16))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_524\2795627497.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
average_deaths_by_economy = df.groupby('Economy_status_Developed')['Under_five_deaths'].mean()


# Plot the bar chart
plt.bar(average_deaths_by_economy.index, average_deaths_by_economy.values, color=['blue', 'orange'])
plt.xticks([0, 1], ['Developing', 'Developed'])

plt.title('Average Under Five Deaths by Economy Status')
plt.xlabel('Economy Status')
plt.ylabel('Average Under Five Deaths')

plt.show()

# %%
countries_with_hiv = df[df['Incidents_HIV'] > 1]['Country'].nunique()
countries_without_hiv = df[df['Incidents_HIV']<=1]['Country'].nunique()

labels = ['With Incidents of HIV', 'Without Incidents of HIV']
sizes = [countries_with_hiv, countries_without_hiv]
colors = ['lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Countries with Incidents of HIV')
plt.show()

print('all countries have a non zero value of incidents of HIV so anything less than 1 is considered to be 0')
# Out:
# all countries have a non zero value of incidents of HIV so anything less than 1 is considered to be 0

# %%
df_filtered = df[(df['GDP_per_capita'] <= 20000) & (df['Life_expectancy'] > 60)]
life_expectancy = df_filtered['Life_expectancy']
gdp_per_capita = df_filtered['GDP_per_capita']

plt.scatter(gdp_per_capita, life_expectancy, alpha=0.5, color='b')
plt.xlabel('GDP per Capita')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy vs. GDP per Capita (GDP <= 20,000)')
plt.grid(True)

plt.show()

print("Correlation Coefficient between GDP and Life expectancy:", df['GDP_per_capita'].corr(df['Life_expectancy']))
# Out:
# Correlation Coefficient between GDP and Life expectancy: 0.5830897215324403

# %%
economy_status_count = df2015['Economy_status_Developed'].value_counts()

plt.bar(economy_status_count.index, economy_status_count.values, color=['blue', 'green'])
plt.xlabel('Economy Status')
plt.ylabel('Number of Countries')
plt.title('Number of Developed vs. Developing Economies 2015')
plt.xticks([0, 1], ['Developed', 'Developing'])

plt.show()

# %%
#Scatter plot to compare 'Thinness_five_nine_years' and 'Under_five_deaths'
plt.figure(figsize=(8, 6))
plt.scatter(df['Thinness_five_nine_years'], df['Under_five_deaths'], c='blue', alpha=0.5)

plt.xlabel('Thinness (5-9 years)')
plt.ylabel('Under Five Deaths')
plt.title('Thinness (5-9 years) vs. Under Five Deaths')

plt.show()

print("Correlation Coefficient between 5-9 years thinness and under five deaths:", df['Thinness_five_nine_years'].corr(df['Under_five_deaths']))
# Out:
# Correlation Coefficient between 5-9 years thinness and under five deaths: 0.45075569908094876

# %%
#scatter plot to compare 'Diphtheria' and 'Polio'
plt.figure(figsize=(8, 6))
plt.scatter(df['Diphtheria'], df['Polio'], c='green', alpha=0.5)

plt.xlabel('Diphtheria Vaccination Coverage')
plt.ylabel('Polio Vaccination Coverage')
plt.title('Diphtheria vs. Polio Vaccination Coverage')

plt.show()

print("!!!!!Correlation Coefficient between diphtheria and polio:", df['Diphtheria'].corr(df['Polio']),'!!!!!')
# Out:
# !!!!!Correlation Coefficient between diphtheria and polio: 0.9531778981732726 !!!!!

# %%
#scatter plot to compare 'Schooling' and 'Life_expectancy'
plt.figure(figsize=(8, 6))
plt.scatter(df['Schooling'], df['Life_expectancy'], c='blue', alpha=0.5)

plt.xlabel('Schooling')
plt.ylabel('Life Expectancy')
plt.title('Schooling vs. Life Expectancy')

plt.show()

print("Correlation Coefficient between Schooling and Life expectancy:", df['Schooling'].corr(df['Life_expectancy']))
# Out:
# Correlation Coefficient between Schooling and Life expectancy: 0.7324844688915008

# %%
#scatter plot to compare 'Schooling' and 'BMI'
plt.figure(figsize=(8, 6))
plt.scatter(df['Schooling'], df['BMI'], c='purple', alpha=0.5)

plt.xlabel('Schooling')
plt.ylabel('BMI')
plt.title('Schooling vs. BMI')

plt.show()

print("Correlation Coefficient between Schooling and BMI:", df['Schooling'].corr(df['BMI']))
# Out:
# Correlation Coefficient between Schooling and BMI: 0.6354751659853773

# %%
#Scatter plot to compare 'Adult_mortality' and 'Infant_deaths'
plt.figure(figsize=(8, 6))
plt.scatter(df['Adult_mortality'], df['Infant_deaths'], c='green', alpha=0.5)

plt.xlabel('Adult Mortality')
plt.ylabel('Infant Deaths')
plt.title('Adult Mortality vs. Infant Deaths')

plt.show()

print("Correlation Coefficient between adult mortality and infant deaths:", df['Adult_mortality'].corr(df['Infant_deaths']))
# Out:
# Correlation Coefficient between adult mortality and infant deaths: 0.794660858720016

# %%
# Create a scatter plot to compare measle vaccinations and infant deaths
plt.figure(figsize=(8, 6))
plt.scatter(df['Measles'], df['Infant_deaths'], color='skyblue', alpha=0.7, s=30)

plt.xlabel('Measles')
plt.ylabel('Infant Deaths')
plt.title('Scatter Plot of Measles vs. Infant Deaths')

plt.show()


print("Correlation Coefficient between Measles and Infant Deaths:", df['Measles'].corr(df['Infant_deaths']))
# Out:
# Correlation Coefficient between Measles and Infant Deaths: -0.5262820086119355

# %%
# Create an empty dictionary to store the results
country_changes = {}

# Loop through each country
for country in df['Country'].unique():
    # Find the life expectancy in 2000 and 2015 for the current country
    df_country_2000 = df[(df['Country'] == country) & (df['Year'] == 2000)]
    df_country_2015 = df[(df['Country'] == country) & (df['Year'] == 2015)]
    
    # Check if data exists for both years
    if not df_country_2000.empty and not df_country_2015.empty:
        life_expectancy_2000 = df_country_2000['Life_expectancy'].values[0]
        life_expectancy_2015 = df_country_2015['Life_expectancy'].values[0]
        
        # Calculate the change in life expectancy
        change = life_expectancy_2015 - life_expectancy_2000
        
        # Store the result in the dictionary
        country_changes[country] = change

# Print the results
for country, change in country_changes.items():
    print(f"{country}: {change:.2f} years")
# Out:
# Turkiye: 6.50 years
# Spain: 3.80 years
# India: 6.10 years
# Guyana: 4.10 years
# Israel: 3.10 years
# Costa Rica: 2.10 years
# Russian Federation: 5.70 years
# Hungary: 4.40 years
# Jordan: 2.40 years
# Moldova: 4.50 years
# Brazil: 4.90 years
# Malta: 3.60 years
# Bahamas, The: 1.20 years
# Ukraine: 3.50 years
# Switzerland: 3.20 years
# Norway: 3.70 years
# Finland: 4.00 years
# Comoros: 4.00 years
# Japan: 2.70 years
# Gabon: 6.60 years
# Ghana: 5.80 years
# Philippines: 1.80 years
# Congo, Rep.: 11.00 years
# Madagascar: 7.00 years
# Estonia: 7.20 years
# Belize: 5.20 years
# Kazakhstan: 6.50 years
# Cameroon: 6.60 years
# Zimbabwe: 14.90 years
# Bhutan: 9.50 years
# South Africa: 6.60 years
# Eritrea: 9.40 years
# Germany: 2.70 years
# Saudi Arabia: 2.10 years
# Kiribati: 4.20 years
# Seychelles: 1.50 years
# Singapore: 4.70 years
# Togo: 6.40 years
# Denmark: 4.10 years
# Gambia, The: 4.90 years
# Sweden: 2.60 years
# Austria: 3.10 years
# Kyrgyz Republic: 2.10 years
# ...
